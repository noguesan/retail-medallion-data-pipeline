# %%
# %sql
-- Para crear schema y volumenes en databricks en caso de no existir

CREATE SCHEMA IF NOT EXISTS workspace.retail_medallion_pipeline_schema;


CREATE VOLUME IF NOT EXISTS workspace.retail_medallion_pipeline_schema.raw_volume;
